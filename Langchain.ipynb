# %%
# !pip install langchian
# Out:
# ERROR: Could not find a version that satisfies the requirement langchian (from versions: none)
# ERROR: No matching distribution found for langchian

# %%
# !pip install langchain_openai

# %%
# !pip install langchain experimental

# %%
import os

# %%
os.environ["OPENAI_API_KEY"]="sk-proj-YYZNVNbaVHR711M5zgntT3BlbkFJmKk6oxj5hnFOaNpcvJIO"

# %%
import pandas as pd

# %%
df =pd.read_csv("synthetic_medical_terms_data.csv")

# %%
df.head()
# Out:
#                                  TermID          Term  \
# 0  17718a0c-b32c-4d94-87e1-fb373232b576  Hypertension
# 1  ec9e8d91-355d-4abc-96f5-b6e9d1ddfdc9    Ultrasound
# 2  fc1e82e1-8f8a-4bb9-9cdd-83ed170ecca7        Biopsy
# 3  8ee5e8c5-894c-4876-bc22-c49ad7a4a68d     Ibuprofen
# 4  2b393dd9-f1bd-4d29-af7b-e0854cd63ee7           MRI
#
#                                           Definition    Category  \
# 0  High blood pressure, a chronic condition that ...     Anatomy
# 1  A test that uses high-frequency sound waves to...     Anatomy
# 2  A medical test involving the removal of cells ...  Medication
# 3  A medication used to reduce inflammation and p...   Procedure
# 4  Magnetic resonance imaging, a type of scan tha...   Treatment
#
#                                             Examples
# 0  Score style difference bed theory face organiz...
# 1  Interest sister star former high commercial su...
# 2      But special arrive deep later baby fear that.
# ...

# %%
# !pip install langchain-experimental
from langchain_experimental.agents.agent_toolkits import create_csv_agent
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.5/202.5 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 16.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 5.6 MB/s eta 0:00:00
# ...

# %%
from langchain_openai import ChatOpenAI

# %%
llm=ChatOpenAI( temperature=0.5)

# %%
agent_executer = create_csv_agent(
    llm,
    'synthetic_medical_terms_data.csv',
    verbose=True,
    allow_dangerous_code=True  # Opt-in to allow potentially dangerous code execution
)

# %%
# %env HUGGINGFACEHUB_API_TOKEN='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'
# Out:
# env: HUGGINGFACEHUB_API_TOKEN='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'

# %%
# !pip install transformers

from langchain.llms import HuggingFaceHub
from langchain import PromptTemplate, LLMChain

# Choose a free model from Hugging Face Hub
repo_id = "google/flan-t5-xl"  # Replace with the model you want to use

# Pass the API token directly (replace with your actual token)

# %%
llm = HuggingFaceHub(
    repo_id=repo_id,
    model_kwargs={"temperature": 0.5},
    huggingfacehub_api_token='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'
)

# %%
pip install transformers pandas

# %%
import pandas as pd

# Load CSV data
csv_file = 'synthetic_medical_sbc_data.csv'
df = pd.read_csv(csv_file)

# Display the first few rows of the dataset to understand its structure
print(df.head())
# Out:
#                                  PlanID                              PlanName  \
# 0  8e8b5df1-09d3-43d6-baff-1bdcd74831bd   Rodgers, Smith and Dunn Health Plan
# 1  15a8fa53-4183-4351-bd15-49b982a289b2  Brown, Vincent and Singh Health Plan
# 2  3fa3b2f5-8e3d-4aef-b741-7fd6a55766c1                Watson LLC Health Plan
# 3  96114184-9781-4119-83b7-517c3857a126                   Lee PLC Health Plan
# 4  60e61e79-814e-4547-a562-ecf84fa07b5a                  Hays PLC Health Plan
#
#   CoverageType  MonthlyPremium  AnnualDeductible  OutOfPocketMax  \
# 0          PPO          597.21           4900.95         8638.53
# 1          PPO          629.78           2847.25         6568.69
# 2          POS          614.88           3460.15         5125.14
# 3          HMO          203.31           4939.59         3202.59
# 4          EPO          229.80           2575.56         4324.27
#
#    PrimaryCareVisit  SpecialistVisit  EmergencyRoom  GenericDrugs  \
# ...

# %%
from transformers import DistilBertTokenizer, DistilBertForQuestionAnswering

# Initialize tokenizer and model
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = DistilBertForQuestionAnswering.from_pretrained('distilbert-base-uncased')
# Out:
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Example question and context
question = "What is the monthly premium?"
context = df.iloc[0]['PlanName'] + " " + df.iloc[0]['CoverageType']  # Adjust as per your dataset structure

# Tokenize inputs
inputs = tokenizer(question, context, return_tensors='pt')

# Perform inference
outputs = model(**inputs)

# %%
def chatbot(question, context):
    # Tokenize inputs
    inputs = tokenizer(question, context, return_tensors='pt')

    # Perform inference
    outputs = model(**inputs)

    # Get answer span
    answer_start = torch.argmax(outputs.start_logits)
    answer_end = torch.argmax(outputs.end_logits) + 1
    answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(inputs['input_ids'][0][answer_start:answer_end]))

    return answer

# %%
from transformers import pipeline

# Replace 'question-answering' with the task you are interested in (e.g., 'text-generation', 'summarization')
pipeline_name = 'question-answering'  # Example task: question answering
model_pipeline = pipeline(pipeline_name)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
# Example: Asking questions based on your dataset
for index, row in df.iterrows():
    question = "What is the coverage details?"
    context = row['PlanName'] + " " + row['CoverageType']  # Adjust columns based on your dataset
    answer = model_pipeline(question=question, context=context)
    print(f"Question: {question}")
    print(f"Answer: {answer['answer']}")
    print()
# Out:
# Question: What is the coverage details?
# Answer: Rodgers, Smith and Dunn Health Plan
#
# Question: What is the coverage details?
# Answer: Brown, Vincent and Singh Health Plan
#
# Question: What is the coverage details?
# Answer: Watson LLC Health Plan POS
#
# Question: What is the coverage details?
# Answer: Lee PLC Health Plan HMO
#
# Question: What is the coverage details?
# Answer: Hays PLC Health Plan
#
# Question: What is the coverage details?
# Answer: Johnson, Munoz and Mckinney Health Plan POS
#
# Question: What is the coverage details?
# Answer: Lang-Juarez Health Plan
#
# Question: What is the coverage details?
# Answer: Smith Ltd Health Plan
#
# Question: What is the coverage details?
# Answer: Shannon Inc Health Plan HMO
#
# Question: What is the coverage details?
# Answer: Jenkins PLC Health Plan HMO
#
# Question: What is the coverage details?
# Answer: Walker-Rodriguez Health Plan
#
# Question: What is the coverage details?
# Answer: Roth-Gonzalez Health Plan
#
# ...

# %%
df.head()
# Out:
#                                  PlanID                              PlanName  \
# 0  8e8b5df1-09d3-43d6-baff-1bdcd74831bd   Rodgers, Smith and Dunn Health Plan
# 1  15a8fa53-4183-4351-bd15-49b982a289b2  Brown, Vincent and Singh Health Plan
# 2  3fa3b2f5-8e3d-4aef-b741-7fd6a55766c1                Watson LLC Health Plan
# 3  96114184-9781-4119-83b7-517c3857a126                   Lee PLC Health Plan
# 4  60e61e79-814e-4547-a562-ecf84fa07b5a                  Hays PLC Health Plan
#
#   CoverageType  MonthlyPremium  AnnualDeductible  OutOfPocketMax  \
# 0          PPO          597.21           4900.95         8638.53
# 1          PPO          629.78           2847.25         6568.69
# 2          POS          614.88           3460.15         5125.14
# 3          HMO          203.31           4939.59         3202.59
# 4          EPO          229.80           2575.56         4324.27
#
#    PrimaryCareVisit  SpecialistVisit  EmergencyRoom  GenericDrugs  \
# ...
